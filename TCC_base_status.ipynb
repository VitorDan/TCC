# %%
import pandas as pd
import os
import nltk
import json
from utils.merge_data import *

# %%
df = pd.read_csv("./data/movies.csv")
df
# Out:
#          Unnamed: 0  review_id         reviewer  \
# 0                 0  rw5704482    raeldor-96879
# 1                 1  rw5704483          dosleeb
# 2                 2  rw5704484  brightconscious
# 3                 3  rw5704485       gasconyway
# 4                 4  rw5704487     mmason-15867
# ...             ...        ...              ...
# 5571494     1014995  rw0528641        generic-2
# 5571495     1014996  rw0528642          Gooch-4
# 5571496     1014997  rw0528643       misternuts
# 5571497     1014998  rw0528644          BruceMc
# 5571498     1014999  rw0528645           Habu-2
#
#                                  movie  rating  \
# 0                  After Life (2019– )     9.0
# 1        The Valhalla Murders (2019– )     6.0
# 2                 Special OPS (2020– )     7.0
# 3                    #BlackAF (2020– )     8.0
# 4                   The Droving (2020)     2.0
# ...                                ...     ...
# 5571494             The Insider (1999)    10.0
# ...

# %%
df = df[['movie','rating','review_summary','review_detail']]
df
# Out:
#                                  movie  rating  \
# 0                  After Life (2019– )     9.0
# 1        The Valhalla Murders (2019– )     6.0
# 2                 Special OPS (2020– )     7.0
# 3                    #BlackAF (2020– )     8.0
# 4                   The Droving (2020)     2.0
# ...                                ...     ...
# 5571494             The Insider (1999)    10.0
# 5571495             The Insider (1999)     NaN
# 5571496             The Insider (1999)     8.0
# 5571497             The Insider (1999)     NaN
# 5571498             The Insider (1999)     9.0
#
#                                             review_summary  \
# 0                                     Very Strong Season 2
# 1                                    Icelandic detectives?
# 2                                          Nothing special
# 3                                                 Good but
# 4                                         An honest review
# ...

# %%
df = df.dropna()
df
# Out:
#                                  movie  rating  \
# 0                  After Life (2019– )     9.0
# 1        The Valhalla Murders (2019– )     6.0
# 2                 Special OPS (2020– )     7.0
# 3                    #BlackAF (2020– )     8.0
# 4                   The Droving (2020)     2.0
# ...                                ...     ...
# 5571491             The Insider (1999)    10.0
# 5571493             The Insider (1999)     9.0
# 5571494             The Insider (1999)    10.0
# 5571496             The Insider (1999)     8.0
# 5571498             The Insider (1999)     9.0
#
#                                             review_summary  \
# 0                                     Very Strong Season 2
# 1                                    Icelandic detectives?
# 2                                          Nothing special
# 3                                                 Good but
# 4                                         An honest review
# ...

# %%
df.to_csv('./data/processed_movies.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.to_csv('./data/processed_movies.csv')
#       2 df = pd.read_csv("./data/processed_movies.csv")
#
# NameError: name 'df' is not defined

# %%
import gc

del df
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 import gc
# ----> 3 del df
#       4 gc.collect()
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("./data/processed_movies.csv")

# %%
df
# Out:
#          Unnamed: 0                          movie  rating  \
# 0                 0            After Life (2019– )     9.0
# 1                 1  The Valhalla Murders (2019– )     6.0
# 2                 2           Special OPS (2020– )     7.0
# 3                 3              #BlackAF (2020– )     8.0
# 4                 4             The Droving (2020)     2.0
# ...             ...                            ...     ...
# 4908600     5571491             The Insider (1999)    10.0
# 4908601     5571493             The Insider (1999)     9.0
# 4908602     5571494             The Insider (1999)    10.0
# 4908603     5571496             The Insider (1999)     8.0
# 4908604     5571498             The Insider (1999)     9.0
#
#                                             review_summary  \
# 0                                     Very Strong Season 2
# 1                                    Icelandic detectives?
# 2                                          Nothing special
# ...
